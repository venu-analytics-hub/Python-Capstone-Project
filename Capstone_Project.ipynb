# %% [markdown]
# <a href="https://colab.research.google.com/github/venu-analytics-hub/Python-Capstone-Project/blob/main/Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task 1: Create Three DataFrames and Save as CSV Files

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# Create sample data for demonstration purposes (replace with actual if available)
project_data = {
    'ID': ['A001', 'A002', 'A003', 'A004', 'A005'],
    'Project': ['Project1', 'Project2', 'Project3', 'Project4', 'Project5'],
    'Cost': [1000000, np.nan, 850000, np.nan, 680000],
    'Status': ['Finished', 'Ongoing', 'Finished', 'Failed', 'Failed']
}
employee_data = {
    'ID': ['A001', 'A002', 'A003', 'A004', 'A005'],
    'Name': ['John Alter', 'Alice Luxumberg', 'Bob Marley', 'Sophia Lane', 'Amy Johny'],
    'Gender': ['M', 'F', 'M', 'F', 'F'],
    'City': ['London', 'Toronto', 'Berlin', 'Madrid', 'Oslo'],
    'Age': [32, 29, 30, 28, 27]
}
seniority_data = {
    'ID': ['A001', 'A002', 'A003', 'A004', 'A005'],
    'Designation Level': [2, 3, 1, 2, 3]
}

# Convert dictionaries to DataFrames
project_df = pd.DataFrame(project_data)
employee_df = pd.DataFrame(employee_data)
seniority_df = pd.DataFrame(seniority_data)

# Save to CSV files
project_df.to_csv('project.csv', index=False)
employee_df.to_csv('employee.csv', index=False)
seniority_df.to_csv('seniority.csv', index=False)

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# Create sample data for demonstration purposes (replace with actual if available)
project_data = {
    'ID': ['A001', 'A002', 'A003', 'A004', 'A005'],
    'Project': ['Project1', 'Project2', 'Project3', 'Project4', 'Project5'],
    'Cost': [1000000, np.nan, 850000, np.nan, 680000],
    'Status': ['Finished', 'Ongoing', 'Finished', 'Failed', 'Failed']
}
employee_data = {
    'ID': ['A001', 'A002', 'A003', 'A004', 'A005'],
    'Name': ['John Alter', 'Alice Luxumberg', 'Bob Marley', 'Sophia Lane', 'Amy Johny'],
    'Gender': ['M', 'F', 'M', 'F', 'F'],
    'City': ['London', 'Toronto', 'Berlin', 'Madrid', 'Oslo'],
    'Age': [32, 29, 30, 28, 27]
}
seniority_data = {
    'ID': ['A001', 'A002', 'A003', 'A004', 'A005'],
    'Designation Level': [2, 3, 1, 2, 3]
}

# Convert dictionaries to DataFrames
project_df = pd.DataFrame(project_data)
employee_df = pd.DataFrame(employee_data)
seniority_df = pd.DataFrame(seniority_data)

# Save to CSV files
project_df.to_csv('project.csv', index=False)
employee_df.to_csv('employee.csv', index=False)
seniority_df.to_csv('seniority.csv', index=False)

# %% [markdown]
# # 📊 Capstone Project: Data Handling & Analysis
# This notebook contains Tasks 1 to 10 with complete Python code and output, with each step commented.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# Create sample data for demonstration purposes (replace with actual if available)
project_data = {
    'ID': ['A001', 'A002', 'A003', 'A004', 'A005'],
    'Project': ['Project1', 'Project2', 'Project3', 'Project4', 'Project5'],
    'Cost': [1000000, np.nan, 850000, np.nan, 680000],
    'Status': ['Finished', 'Ongoing', 'Finished', 'Failed', 'Failed']
}
employee_data = {
    'ID': ['A001', 'A002', 'A003', 'A004', 'A005'],
    'Name': ['John Alter', 'Alice Luxumberg', 'Bob Marley', 'Sophia Lane', 'Amy Johny'],
    'Gender': ['M', 'F', 'M', 'F', 'F'],
    'City': ['London', 'Toronto', 'Berlin', 'Madrid', 'Oslo'],
    'Age': [32, 29, 30, 28, 27]
}
seniority_data = {
    'ID': ['A001', 'A002', 'A003', 'A004', 'A005'],
    'Designation Level': [2, 3, 1, 2, 3]
}

# Convert dictionaries to DataFrames
project_df = pd.DataFrame(project_data)
employee_df = pd.DataFrame(employee_data)
seniority_df = pd.DataFrame(seniority_data)

# Save to CSV files
project_df.to_csv('project.csv', index=False)
employee_df.to_csv('employee.csv', index=False)
seniority_df.to_csv('seniority.csv', index=False)

# %% [markdown]
# ## Task 2: Replace Missing Cost Values with Running Average

# %%
# Load CSV
project_df = pd.read_csv('project.csv')

# Replace missing 'Cost' values with running average using a for loop
for i in range(len(project_df)):
    if pd.isna(project_df.loc[i, 'Cost']):
        project_df.loc[i, 'Cost'] = project_df['Cost'][:i].mean()

# View updated DataFrame
project_df
# Out:
#      ID   Project       Cost    Status
# 0  A001  Project1  1000000.0  Finished
# 1  A002  Project2  1000000.0   Ongoing
# 2  A003  Project3   850000.0  Finished
# 3  A004  Project4   950000.0    Failed
# 4  A005  Project5   680000.0    Failed

# %% [markdown]
# ## Task 3: Split Name into First and Last Name

# %%
# Load employee DataFrame
employee_df = pd.read_csv('employee.csv')

# Split 'Name' column into 'First Name' and 'Last Name'
employee_df[['First Name', 'Last Name']] = employee_df['Name'].str.split(' ', n=1, expand=True)
employee_df.drop('Name', axis=1, inplace=True)
employee_df
# Out:
#      ID Gender     City  Age First Name  Last Name
# 0  A001      M   London   32       John      Alter
# 1  A002      F  Toronto   29      Alice  Luxumberg
# 2  A003      M   Berlin   30        Bob     Marley
# 3  A004      F   Madrid   28     Sophia       Lane
# 4  A005      F     Oslo   27        Amy      Johny

# %% [markdown]
# ## Task 4: Join All DataFrames into Final

# %%
# Load seniority DataFrame
seniority_df = pd.read_csv('seniority.csv')

# Merge all DataFrames into one
merged_df = pd.merge(project_df, employee_df, on='ID')
Final = pd.merge(merged_df, seniority_df, on='ID')
Final
# Out:
#      ID   Project       Cost    Status Gender     City  Age First Name  \
# 0  A001  Project1  1000000.0  Finished      M   London   32       John
# 1  A002  Project2  1000000.0   Ongoing      F  Toronto   29      Alice
# 2  A003  Project3   850000.0  Finished      M   Berlin   30        Bob
# 3  A004  Project4   950000.0    Failed      F   Madrid   28     Sophia
# 4  A005  Project5   680000.0    Failed      F     Oslo   27        Amy
#
#    Last Name  Designation Level
# 0      Alter                  2
# 1  Luxumberg                  3
# 2     Marley                  1
# 3       Lane                  2
# 4      Johny                  3

# %% [markdown]
# ## Task 5: Add Bonus Column (5% of Cost if Project is Finished)

# %%
# Add 'Bonus' column
Final['Bonus'] = Final.apply(lambda row: 0.05 * row['Cost'] if row['Status'] == 'Finished' else 0, axis=1)
Final[['ID', 'Cost', 'Status', 'Bonus']]
# Out:
#      ID       Cost    Status    Bonus
# 0  A001  1000000.0  Finished  50000.0
# 1  A002  1000000.0   Ongoing      0.0
# 2  A003   850000.0  Finished  42500.0
# 3  A004   950000.0    Failed      0.0
# 4  A005   680000.0    Failed      0.0

# %% [markdown]
# ## Task 6: Demote Failed Employees and Remove Level > 4

# %%
# Demote designation level by 1 for failed projects
failed_ids = Final[Final['Status'] == 'Failed']['ID'].unique()
Final['Designation Level'] = Final.apply(
    lambda row: row['Designation Level'] + 1 if row['ID'] in failed_ids else row['Designation Level'], axis=1
)

# Remove employees with designation level > 4
Final = Final[Final['Designation Level'] <= 4].reset_index(drop=True)
Final[['ID', 'Status', 'Designation Level']]
# Out:
#      ID    Status  Designation Level
# 0  A001  Finished                  2
# 1  A002   Ongoing                  3
# 2  A003  Finished                  1
# 3  A004    Failed                  3
# 4  A005    Failed                  4

# %% [markdown]
# ## Task 7: Prefix Mr./Mrs. to First Name and Drop Gender

# %%
# Prefix based on gender
Final['First Name'] = Final.apply(
    lambda row: f"Mr. {row['First Name']}" if row['Gender'] == 'M' else f"Mrs. {row['First Name']}", axis=1
)

# Drop Gender column
Final.drop('Gender', axis=1, inplace=True)
Final[['ID', 'First Name', 'Last Name']]
# Out:
#      ID   First Name  Last Name
# 0  A001     Mr. John      Alter
# 1  A002   Mrs. Alice  Luxumberg
# 2  A003      Mr. Bob     Marley
# 3  A004  Mrs. Sophia       Lane
# 4  A005     Mrs. Amy      Johny

# %% [markdown]
# ## Task 8: Promote Employees Aged Over 29

# %%
# Promote by reducing level by 1 (minimum is 1)
Final['Designation Level'] = Final.apply(
    lambda row: row['Designation Level'] - 1 if row['Age'] > 29 and row['Designation Level'] > 1 else row['Designation Level'],
    axis=1
)
Final[['ID', 'Age', 'Designation Level']]
# Out:
#      ID  Age  Designation Level
# 0  A001   32                  1
# 1  A002   29                  3
# 2  A003   30                  1
# 3  A004   28                  3
# 4  A005   27                  4

# %% [markdown]
# ## Task 10: Filter Employees Where City Contains 'o'

# %%
# Filter by city name containing 'o'
filtered_employees = Final[Final['City'].str.contains('o', case=False, na=False)]
filtered_employees
# Out:
#      ID   Project       Cost    Status     City  Age  First Name  Last Name  \
# 0  A001  Project1  1000000.0  Finished   London   32    Mr. John      Alter
# 1  A002  Project2  1000000.0   Ongoing  Toronto   29  Mrs. Alice  Luxumberg
# 4  A005  Project5   680000.0    Failed     Oslo   27    Mrs. Amy      Johny
#
#    Designation Level    Bonus
# 0                  1  50000.0
# 1                  3      0.0
# 4                  4      0.0
